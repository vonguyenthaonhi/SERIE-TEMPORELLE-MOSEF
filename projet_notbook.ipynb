# %% [markdown]
# <p align="center">
#     <img src="mosef.png" alt="MOSEF Logo" width="300">
# </p>
# ```
# </p>
#
# <a href="https://linkedin.com/lucasvazelle">Vazelle Lucas et </a> $\cdot$ 2024-2025, MOSEF $\cdot$
#
# ---
#
# This notebook is part of a series of notebooks which explore Data Science topics in Python:
#
# - [Import données](https://cds.climate.copernicus.eu/datasets/)

# %% [markdown]
# # Table of Contents
# ---
# **1. [Télécharger les données](#Introduction)**

# %% [markdown]
# # Télécharger les données

# %% [markdown]
# https://cds.climate.copernicus.eu/datasets/sis-water-level-change-timeseries-cmip6?tab=download

# %% [markdown]
# ## données pour la prévision

# %%
import cdsapi

dataset = "sis-water-level-change-timeseries-cmip6"
request = {
    "variable": ["total_water_level"],
    "experiment": "reanalysis",
    "temporal_aggregation": ["daily_maximum"],
    "year": [
        "2007", "2008", "2009",
        "2010", "2011", "2012",
        "2013", "2014"
    ],
    "month": [
        "01", "02", "03",
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12"
    ]
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()
# Out:
# 2024-11-03 20:48:29,797 INFO [2024-09-28T00:00:00] **Welcome to the New Climate Data Store (CDS)!** This new system is in its early days of full operations and still undergoing enhancements and fine tuning. Some disruptions are to be expected. Your
# [feedback](https://jira.ecmwf.int/plugins/servlet/desk/portal/1/create/202) is key to improve the user experience on the new CDS for the benefit of everyone. Thank you.
# 2024-11-03 20:48:29,797 WARNING [2024-09-26T00:00:00] Should you have not yet migrated from the old CDS system to the new CDS, please check our [informative page](https://confluence.ecmwf.int/x/uINmFw) for guidance.
# 2024-11-03 20:48:29,797 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2024-11-03 20:48:29,797 INFO [2024-09-16T00:00:00] Remember that you need to have an ECMWF account to use the new CDS. **Your old CDS credentials will not work in new CDS!**
# ...

# %%
import cdsapi

dataset = "sis-water-level-change-timeseries-cmip6"
request = {
    "variable": ["storm_surge_residual"],
    "experiment": "reanalysis",
    "temporal_aggregation": ["daily_maximum"],
    "year": [
        "2007", "2008", "2009",
        "2010", "2011", "2012",
        "2013", "2014"
    ],
    "month": [
        "01", "02", "03",
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12"
    ]
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()
# Out:
# 2024-11-03 20:52:33,050 INFO [2024-09-28T00:00:00] **Welcome to the New Climate Data Store (CDS)!** This new system is in its early days of full operations and still undergoing enhancements and fine tuning. Some disruptions are to be expected. Your
# [feedback](https://jira.ecmwf.int/plugins/servlet/desk/portal/1/create/202) is key to improve the user experience on the new CDS for the benefit of everyone. Thank you.
# 2024-11-03 20:52:33,050 WARNING [2024-09-26T00:00:00] Should you have not yet migrated from the old CDS system to the new CDS, please check our [informative page](https://confluence.ecmwf.int/x/uINmFw) for guidance.
# 2024-11-03 20:52:33,050 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2024-11-03 20:52:33,050 INFO [2024-09-16T00:00:00] Remember that you need to have an ECMWF account to use the new CDS. **Your old CDS credentials will not work in new CDS!**
# ...

# %%
import cdsapi

dataset = "sis-water-level-change-timeseries-cmip6"
request = {
    "variable": ["mean_sea_level"],
    "experiment": "historical",
    "temporal_aggregation": ["annual"],
    "year": [
        "2007", "2008", "2009",
        "2010", "2011", "2012",
        "2013", "2014"
    ]
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()
# Out:
# 2024-11-04 14:39:54,235 INFO [2024-09-28T00:00:00] **Welcome to the New Climate Data Store (CDS)!** This new system is in its early days of full operations and still undergoing enhancements and fine tuning. Some disruptions are to be expected. Your
# [feedback](https://jira.ecmwf.int/plugins/servlet/desk/portal/1/create/202) is key to improve the user experience on the new CDS for the benefit of everyone. Thank you.
# 2024-11-04 14:39:54,236 WARNING [2024-09-26T00:00:00] Should you have not yet migrated from the old CDS system to the new CDS, please check our [informative page](https://confluence.ecmwf.int/x/uINmFw) for guidance.
# 2024-11-04 14:39:54,237 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2024-11-04 14:39:54,238 INFO [2024-09-16T00:00:00] Remember that you need to have an ECMWF account to use the new CDS. **Your old CDS credentials will not work in new CDS!**
# ...

# %%
import cdsapi

dataset = "sis-water-level-change-timeseries-cmip6"
request = {
    "variable": ["mean_sea_level"],
    "experiment": "historical",
    "temporal_aggregation": ["annual"],
    "year": [
        "1950", "1951", "1952",
        "1953", "1954", "1955",
        "1956", "1957", "1958",
        "1959", "1960", "1961",
        "1962", "1963", "1964",
        "1965", "1966", "1967",
        "1968", "1969", "1970",
        "1971", "1972", "1973",
        "1974", "1975", "1976",
        "1977", "1978", "1979",
        "1980", "1981", "1982",
        "1983", "1984", "1985",
        "1986", "1987", "1988",
        "1989", "1990", "1991",
        "1992", "1993", "1994",
        "1995", "1996", "1997",
        "1998", "1999", "2000",
        "2001", "2002", "2003",
        "2004", "2005", "2006",
        "2007", "2008", "2009",
        "2010", "2011", "2012",
        "2013", "2014"
    ]
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()
# Out:
# 2024-11-04 14:55:56,660 INFO [2024-09-28T00:00:00] **Welcome to the New Climate Data Store (CDS)!** This new system is in its early days of full operations and still undergoing enhancements and fine tuning. Some disruptions are to be expected. Your
# [feedback](https://jira.ecmwf.int/plugins/servlet/desk/portal/1/create/202) is key to improve the user experience on the new CDS for the benefit of everyone. Thank you.
# 2024-11-04 14:55:56,660 WARNING [2024-09-26T00:00:00] Should you have not yet migrated from the old CDS system to the new CDS, please check our [informative page](https://confluence.ecmwf.int/x/uINmFw) for guidance.
# 2024-11-04 14:55:56,660 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2024-11-04 14:55:56,660 INFO [2024-09-16T00:00:00] Remember that you need to have an ECMWF account to use the new CDS. **Your old CDS credentials will not work in new CDS!**
# ...

# %%
import cdsapi

dataset = "sis-water-level-change-timeseries-cmip6"
request = {
    "variable": ["total_water_level"],
    "experiment": "reanalysis",
    "temporal_aggregation": ["10_min"],
   "year": [
        "2007", "2008", "2009",
        "2010", "2011", "2012",
        "2013", "2014"
    ],
    "month": [
        "01", "02", "03",
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12"
    ]
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()
# Out:
# 2024-11-04 14:41:43,839 INFO [2024-09-28T00:00:00] **Welcome to the New Climate Data Store (CDS)!** This new system is in its early days of full operations and still undergoing enhancements and fine tuning. Some disruptions are to be expected. Your
# [feedback](https://jira.ecmwf.int/plugins/servlet/desk/portal/1/create/202) is key to improve the user experience on the new CDS for the benefit of everyone. Thank you.
# 2024-11-04 14:41:43,839 WARNING [2024-09-26T00:00:00] Should you have not yet migrated from the old CDS system to the new CDS, please check our [informative page](https://confluence.ecmwf.int/x/uINmFw) for guidance.
# 2024-11-04 14:41:43,839 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2024-11-04 14:41:43,848 INFO [2024-09-16T00:00:00] Remember that you need to have an ECMWF account to use the new CDS. **Your old CDS credentials will not work in new CDS!**
# ...

# %%
import cdsapi

dataset = "sis-water-level-change-timeseries-cmip6"
request = {
    "variable": ["storm_surge_residual"],
    "experiment": "reanalysis",
    "temporal_aggregation": ["10_min"],
    "year": [
        "2007", "2008", "2009",
        "2010", "2011", "2012",
        "2013", "2014"
    ],
    "month": [
        "01", "02", "03",
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12"
    ]
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()

# %% [markdown]
# ## benchmark prediction by copernicus

# %%
import cdsapi

dataset = "sis-water-level-change-timeseries-cmip6"
request = {
    "variable": ["mean_sea_level"],
    "experiment": "future",
    "temporal_aggregation": ["annual"],
    "year": [
        "2015", "2016", "2017",
        "2018", "2019"
    ]
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()
# Out:
# 2024-11-04 14:57:21,619 INFO [2024-09-28T00:00:00] **Welcome to the New Climate Data Store (CDS)!** This new system is in its early days of full operations and still undergoing enhancements and fine tuning. Some disruptions are to be expected. Your
# [feedback](https://jira.ecmwf.int/plugins/servlet/desk/portal/1/create/202) is key to improve the user experience on the new CDS for the benefit of everyone. Thank you.
# 2024-11-04 14:57:21,619 WARNING [2024-09-26T00:00:00] Should you have not yet migrated from the old CDS system to the new CDS, please check our [informative page](https://confluence.ecmwf.int/x/uINmFw) for guidance.
# 2024-11-04 14:57:21,619 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2024-11-04 14:57:21,635 INFO [2024-09-16T00:00:00] Remember that you need to have an ECMWF account to use the new CDS. **Your old CDS credentials will not work in new CDS!**
# ...

# %%
import cdsapi

dataset = "sis-water-level-change-timeseries-cmip6"
request = {
    "variable": ["mean_sea_level"],
    "experiment": "future",
    "temporal_aggregation": ["annual"],
    "year": [
        "2015", "2016", "2017",
        "2018", "2019", "2020",
        "2021", "2022", "2023",
        "2024", "2025", "2026",
        "2027", "2028", "2029",
        "2030", "2031", "2032",
        "2033", "2034", "2035",
        "2036", "2037", "2038",
        "2039", "2040", "2041",
        "2042", "2043", "2044",
        "2045", "2046", "2047",
        "2048", "2049", "2050"
    ]
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()
# Out:
# 2024-11-04 14:57:36,451 INFO [2024-09-28T00:00:00] **Welcome to the New Climate Data Store (CDS)!** This new system is in its early days of full operations and still undergoing enhancements and fine tuning. Some disruptions are to be expected. Your
# [feedback](https://jira.ecmwf.int/plugins/servlet/desk/portal/1/create/202) is key to improve the user experience on the new CDS for the benefit of everyone. Thank you.
# 2024-11-04 14:57:36,451 WARNING [2024-09-26T00:00:00] Should you have not yet migrated from the old CDS system to the new CDS, please check our [informative page](https://confluence.ecmwf.int/x/uINmFw) for guidance.
# 2024-11-04 14:57:36,451 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2024-11-04 14:57:36,451 INFO [2024-09-16T00:00:00] Remember that you need to have an ECMWF account to use the new CDS. **Your old CDS credentials will not work in new CDS!**
# ...

# %%
import cdsapi

dataset = "sis-water-level-change-timeseries-cmip6"
request = {
    "variable": ["mean_sea_level"],
    "experiment": "future",
    "temporal_aggregation": ["annual"],
    "year": [
        "2015", "2016", "2017",
        "2018", "2019"
    ]
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()

# %%
import cdsapi

dataset = "sis-water-level-change-timeseries-cmip6"
request = {
    "variable": ["tidal_elevation"],
    "experiment": "future",
    "model": ["cmcc_cm2_vhr4"],
    "temporal_aggregation": ["10_min"],
    "year": [
        "2015", "2016", "2017",
        "2018", "2019"
    ],
    "month": [
        "01", "02", "03",
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12"
    ]
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()

# %%
import cdsapi

dataset = "sis-water-level-change-timeseries-cmip6"
request = {
    "variable": ["total_water_level"],
    "experiment": "future",
    "model": ["cmcc_cm2_vhr4"],
    "temporal_aggregation": ["10_min"],
    "year": [
        "2015", "2016", "2017",
        "2018", "2019"
    ],
    "month": [
        "01", "02", "03",
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12"
    ]
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()

# %%
import cdsapi

dataset = "sis-water-level-change-timeseries-cmip6"
request = {
    "variable": ["storm_surge_residual"],
    "experiment": "future",
    "model": ["cmcc_cm2_vhr4"],
    "temporal_aggregation": ["10_min"],
    "year": [
        "2015", "2016", "2017",
        "2018", "2019"
    ],
    "month": [
        "01", "02", "03",
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12"
    ]
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()

# %% [markdown]
# # Exploration données

# %%
import xarray as xr
import os
import numpy as np
import pandas as pd

# Fonction pour charger un fichier NetCDF
def load_netcdf_data(nc_file):
    return xr.open_dataset(nc_file, engine="netcdf4")

# Fonction pour charger tous les fichiers NetCDF d'un répertoire (et de ses sous-répertoires)
def load_all_netcdf_files(directory):
    datasets = []
    filenames = []
    seen_files = set()  # Pour suivre les fichiers déjà rencontrés
    
    # Parcours récursif du répertoire et de ses sous-répertoires
    for root, dirs, files in os.walk(directory):
        for filename in files:
            # Vérifier si le fichier est un fichier NetCDF (.nc)
            if filename.endswith(".nc"):
                file_path = os.path.join(root, filename)
                
                # Si le fichier n'a pas déjà été rencontré, le traiter
                if file_path not in seen_files:
                    seen_files.add(file_path)
                    
                    # Tenter de charger le fichier NetCDF
                    dataset = load_netcdf_data(file_path)
                    if dataset is not None:  # Si le fichier est chargé avec succès
                        datasets.append(dataset)
                        filenames.append(file_path)  # Ajouter le chemin complet du fichier

    return datasets, filenames

# Fonction pour extraire un titre pertinent basé sur le nom du fichier
def extract_title(filename):
    start = filename.find("_") + 1
    end = filename.find("-", start)
    return filename[start:end].replace("_", " ").capitalize()

# %%
pip install netCDF4 h5py h5netcdf store scipy
# Out:
# ...
#    ---------------------------------------- 0.0/44.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/44.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/44.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/44.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/44.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/44.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/44.8 MB ? eta -:--:--
#    ---------------------------------------- 0.5/44.8 MB 349.5 kB/s eta 0:02:07
#    ---------------------------------------- 0.5/44.8 MB 349.5 kB/s eta 0:02:07
#    ---------------------------------------- 0.5/44.8 MB 349.5 kB/s eta 0:02:07
#    ---------------------------------------- 0.5/44.8 MB 349.5 kB/s eta 0:02:07
#     --------------------------------------- 0.8/44.8 MB 357.1 kB/s eta 0:02:04
#     --------------------------------------- 0.8/44.8 MB 357.1 kB/s eta 0:02:04
# ...

# %%
import os

file_path = r"c:\Users\lucas\OneDrive\Documents\M2 MSOEF\série temporelle\PROJET\SERIE-TEMPORELLE-MOSEF\src\14_extreme_precipitation_total-reanalysis-yearly-grid-1940-2023-v1.0.nc"
print(os.path.exists(file_path))  # This will return True if the file exists
# Out:
# True

# %%
def load_netcdf_data(nc_file):
    return xr.open_dataset(nc_file, engine="netcdf4")

# Fonction pour charger tous les fichiers NetCDF d'un répertoire (et de ses sous-répertoires)
def load_all_netcdf_files(directory):
    datasets = []
    filenames = []
    seen_files = set()  # Pour suivre les fichiers déjà rencontrés
    
    # Parcours récursif du répertoire et de ses sous-répertoires
    for root, dirs, files in os.walk(directory):
        for filename in files:
            # Vérifier si le fichier est un fichier NetCDF (.nc)
            if filename.endswith(".nc"):
                file_path = os.path.join(root, filename)
                
                # Si le fichier n'a pas déjà été rencontré, le traiter
                if file_path not in seen_files:
                    seen_files.add(file_path)
                    
                    # Tenter de charger le fichier NetCDF
                    dataset = load_netcdf_data(file_path)
                    if dataset is not None:  # Si le fichier est chargé avec succès
                        datasets.append(dataset)
                        filenames.append(file_path)  # Ajouter le chemin complet du fichier

    return datasets, filenames

# %%
datasets, filenames = load_all_netcdf_files(".")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\lucas\OneDrive\Documents\M2 MSOEF\série temporelle\PROJET\SERIE-TEMPORELLE-MOSEF\.venv\Lib\site-packages\xarray\backends\file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File c:\Users\lucas\OneDrive\Documents\M2 MSOEF\série temporelle\PROJET\SERIE-TEMPORELLE-MOSEF\.venv\Lib\site-packages\xarray\backends\lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# ...

# %%
ds = xr.open_dataset("14_extreme_precipitation_total-reanalysis-yearly-grid-1940-2023-v1.0.nc", engine = "netcdf4")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\lucas\OneDrive\Documents\M2 MSOEF\série temporelle\PROJET\SERIE-TEMPORELLE-MOSEF\.venv\Lib\site-packages\xarray\backends\file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File c:\Users\lucas\OneDrive\Documents\M2 MSOEF\série temporelle\PROJET\SERIE-TEMPORELLE-MOSEF\.venv\Lib\site-packages\xarray\backends\lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# ...

# %%
print(os.listdir())
# Out:
# ['14_extreme_precipitation_total-reanalysis-yearly-grid-1940-2023-v1.0.nc', 'data', 'historical_msl_1950_01_v1.nc', 'mosef.png', 'projet_notbook.ipynb', 'test_xarray.py']

# %%
ds = xr.open_dataset("14_extreme_precipitation_total-reanalysis-yearly-grid-1940-2023-v1.0.nc")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\lucas\OneDrive\Documents\M2 MSOEF\série temporelle\PROJET\SERIE-TEMPORELLE-MOSEF\.venv\Lib\site-packages\xarray\backends\file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File c:\Users\lucas\OneDrive\Documents\M2 MSOEF\série temporelle\PROJET\SERIE-TEMPORELLE-MOSEF\.venv\Lib\site-packages\xarray\backends\lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# ...

# %%
# Fonction pour tracer la carte en fonction de l'année
def tracer_carte(annee):
    plt.figure(figsize=(10, 6))
    
    index = ds.time.dt.year == annee
    plt.imshow(ds.tp.sel(time=index).squeeze(), origin='lower', cmap='Reds')
    plt.colorbar(label=' ()')
    plt.title(f'Graphique de  pour l\'année {annee}')
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.show()

# Créer un slider pour sélectionner l'année
annee_slider = widgets.IntSlider(
    value=ds.time.dt.year[0].item(),
    min=ds.time.dt.year.min().item(),
    max=ds.time.dt.year.max().item(),
    step=1,
    description='Année:',
    continuous_update=False
)

interact(tracer_carte, annee=annee_slider)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 15
#      11     plt.show()
#      13 # Créer un slider pour sélectionner l'année
#      14 annee_slider = widgets.IntSlider(
# ---> 15     value=ds.time.dt.year[0].item(),
#      16     min=ds.time.dt.year.min().item(),
#      17     max=ds.time.dt.year.max().item(),
#      18     step=1,
#      19     description='Année:',
#      20     continuous_update=False
#      21 )
#      23 interact(tracer_carte, annee=annee_slider)
#
# NameError: name 'ds' is not defined
